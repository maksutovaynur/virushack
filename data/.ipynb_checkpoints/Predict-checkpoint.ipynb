# %%
import re
import sys
sys.path.append('..')
sys.path.append('../lib')
import stats as S
import json
from importlib import reload
import _pickle as p
import pandas as pd
from IPython.display import display, HTML
S = reload(S)
pd.set_option('display.width',-1)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
display(HTML("<style>.container{width: 100%}</style>"))
# Out:
# /home/aynur/Installed/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   del sys.path[0]
# <style>.container{width: 100%}</style>

# %%
converters={'KwMult': eval, 'KwNorm': eval}
Ph, Sdict, Pdict = map(lambda x: pd.read_csv(x, converters=converters), ["pharma_kw_thr0.010000.csv", "med_terms_kw_thr0.010000.csv", "medical_profs_kw_thr0.010000.csv"])

# %%
all_words = set(sum(Ph['KwNorm'].map(lambda x: list(x.keys())), []))
len(all_words)
# Out:
# 225

# %%
input_text = S.keywords(S.lemm('Голова болит очень сильно'))
display(input_text)
Sdict['tmp'] = Sdict['KwMult'].apply(lambda x: S.multiply2stats(input_text, x, max_dist=2))
Sdict['tmp_sum'] = Sdict['tmp'].apply(S.sum_stat)
sortedSdict = Sdict.sort_values('tmp_sum', ascending=False)
Sdict.head()
# Out:
# {'голова': 1, 'болеть': 1, 'очень': 1, 'сильно': 1}
#    Unnamed: 0  \
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#
#                                                                                                                                                                                                                                                                             Definitions  \
# 0   жидкая часть крови, в которой находятся форменные элементы (эритроциты, лейкоциты, тромбоциты). По изменениям в составе плазмы крови диагностируются различные заболевания (ревматизм, сахарный диабет и тд.). Из плазмы крови готовят лекарственные препараты.
# 1   ограничение подвижности сустава, вызванное рубцовым стягиванием кожи, сухожилий, заболеваниями мышц, сустава, болевым рефлексом, др. причинами.
# ...

# %%
Ph['tmp'] = Ph['KwNorm'].apply(lambda x: S.multiply2stats(input_text, x, max_dist=2))
Ph['tmp_sum'] = Ph['tmp'].apply(S.sum_stat)
PhS = Ph.sort_values('tmp_sum', ascending=False)
PhS.head()
# Out:
#        Unnamed: 0  \
# 0      0
# 12581  15907
# 12597  15928
# 12596  15927
# 12595  15926
#
#                                    PharmaLink-href  \
# 0      https://www.rlsnet.ru/tn_index_id_3684.htm
# 12581  https://www.rlsnet.ru/tn_index_id_50516.htm
# 12597  https://www.rlsnet.ru/tn_index_id_29555.htm
# 12596  https://www.rlsnet.ru/tn_index_id_29569.htm
# 12595  https://www.rlsnet.ru/tn_index_id_67129.htm
#
#                             PharmaName  \
# 0      Энап®-Н (Enap®-H)
# 12581  Эгилок® С (Egilok® S)
# 12597  Элоком® Лосьон (Elocom® Lotion)
# 12596  Эскапел® (Escapelle®)
# 12595  Эгипрес® (Egipres)
#
#                                                       ActiveSubstance  \
# 0      Гидрохлоротиазид + Эналаприл (Hydrochlorothiazide + Enalapril)
# 12581  Метопролол* (Metoprolol*)
# 12597  Мометазон* (Mometasone*)
# 12596  Левоноргестрел* (Levonorgestrel*)
# 12595  Амлодипин + Рамиприл (Amlodipine + Ramipril)
#
# ...
